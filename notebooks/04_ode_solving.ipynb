# %% [markdown]
# # Solving ordinary differential equations

# %%
from utils.test_functions import example_diff_eq, example_analytical_sol
import utils.plot_utils as pltutils
from utils.numerical_algo import ODESolver

# %% [markdown]
# ### Forward Euler method

# %%
# Class implementation

# %%
# Test code

# %% [markdown]
# ### Backward Euler method

# %%
# Class implementation

# %%
# Test code

# %% [markdown]
# ### Euler method with variable step size

# %%
# Class implementation

# %%
# Test code

# %% [markdown]
# ### Tasks

# %% [markdown]
# Simulate the following mechanical system:
#
# Where m is mass, k is spring coefficient, c is dampening coefficient and f(t) is force exerted on the body
#
# ![image.png](attachment:image.png)
